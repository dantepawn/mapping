# %%
import folium
import pandas as pd

import numpy as np

size = 1000
lons = np.random.random_integers(-180, 180, size=size)
lats = np.random.random_integers(-90, 90, size=size)

locations = list(zip(lons, lats))
popups = ['{}'.format(loc) for loc in locations]
# Out:
# <ipython-input-2-22ceef1e2c07>:7: DeprecationWarning: This function is deprecated. Please call randint(-180, 180 + 1) instead
#   lons = np.random.random_integers(-180, 180, size=size)
# <ipython-input-2-22ceef1e2c07>:8: DeprecationWarning: This function is deprecated. Please call randint(-90, 90 + 1) instead
#   lats = np.random.random_integers(-90, 90, size=size)

# %%
from folium.plugins import MarkerCluster

mapa = folium.Map(location=[np.mean(lats), np.mean(lons)],
                  tiles='Cartodb Positron', zoom_start=1)

mapa.add_child(MarkerCluster(locations=locations, popups=popups))

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
