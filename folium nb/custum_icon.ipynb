# %%
import folium

# %%
from folium.features import CustomIcon

mapa = folium.Map(location=[45.372, -121.6972], zoom_start=12,tiles='Stamen Terrain')

#icon_image = "http://leafletjs.com/docs/images/leaf-green.png"
#icon_image = 'https://www.flaticon.com/free-icon/marker_1397897?term=marker&page=1&position=74'
#icon_image =  'https://cdn5.vectorstock.com/i/1000x1000/99/84/map-marker-icon-vector-13489984.jpg'
#icon_image =     'map-marker-icon-vector-13489984.jpg'
icon_image = 'marker.png'
#shadow_image = 'marker.png'
#shadow_image = "http://leafletjs.com/docs/images/leaf-shadow.png"
#https://www.flaticon.com/free-icon/marker_1397897?term=marker&page=1&position=74
#shadow_image = 'https://www.flaticon.com/free-icon/marker_1397897?term=marker&page=1&position=74'
icon = CustomIcon(icon_image,
                  icon_size=(25,25),
                  icon_anchor=(20,20),
#                  shadow_image=shadow_image,
#                  shadow_size=(25,25),
#                  shadow_anchor=(25,25),
                  #popup_anchor=(-3,-76)
                 )

marker = folium.Marker([45.3288, -121.6625], icon=icon,
                           popup='Mt. Hood Meadows')


mapa.add_child(marker)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
